# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5242, 3082, 12, 6, 195, 2, 3136, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'term', 'anarchism', 'of', 'originated', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From C:\Users\Jesus\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.671287
# Nearest to i: computed, rsfsr, risc, disparaging, polyglot, polysaccharide, theorizing, eller,
# Nearest to will: tracking, lured, slanted, vangelis, hamas, silverman, dili, bca,
# Nearest to six: serenity, brings, bckgr, wallach, quartet, wahhab, mauchly, transcontinental,
# Nearest to also: wallets, mentats, rove, abort, kanagawa, hysteria, infectious, ztas,
# Nearest to known: seabirds, breathtaking, itosu, wording, broom, abiathar, drysdale, fijian,
# Nearest to as: zf, whampoa, marrying, faustus, sailboat, greg, ceiba, cinemas,
# Nearest to up: breve, ended, aveiro, punish, amstrad, xxiv, conversations, copulation,
# Nearest to has: compositional, assassinations, dylan, airports, fruitless, jest, grids, gain,
# Nearest to his: depressed, singapore, completion, deutschlands, di, archetype, reclamation, bullets,
# Nearest to they: hopkinson, brindisi, silvia, pius, lies, audiovisual, ascetics, measurement,
# Nearest to which: hells, bubble, resignation, hagen, boltzmann, putatively, stanton, rural,
# Nearest to history: puzzled, epitaph, drucker, banzer, unjustly, supplanting, barium, kontor,
# Nearest to five: biennial, vantaa, overtly, stouffer, verdicts, rask, restart, drafting,
# Nearest to would: fetch, implicit, nourishing, martha, fulfill, rabelais, gleason, bz,
# Nearest to be: thigh, superpowered, albatross, bitwise, bund, prospectors, neorealism, stradella,
# Nearest to he: desu, shared, moulds, weekdays, trams, alighieri, manaus, commodus,
# Average loss at step 2000: 4.366623
# Average loss at step 4000: 3.866433
# Average loss at step 6000: 3.785359
# Average loss at step 8000: 3.687169
# Average loss at step 10000: 3.615742
# Nearest to i: patterson, sociobiology, may, polysaccharide, ministries, horrendous, rsfsr, emmy,
# Nearest to will: would, lured, militant, tracking, andropov, creations, could, can,
# Nearest to six: five, eight, seven, three, four, nine, zero, two,
# Nearest to also: rove, not, mishap, wallets, paulist, which, mentats, disjunctive,
# Nearest to known: used, fijian, drysdale, agenda, breathtaking, such, abiathar, concubine,
# Nearest to as: spitzer, crossed, rotates, cretians, by, spp, apartheid, glyn,
# Nearest to up: ended, breve, xxiv, amstrad, aveiro, punish, lined, enveloping,
# Nearest to has: is, had, was, have, millennial, does, landmarks, jansen,
# Nearest to his: their, her, the, its, toho, s, this, pineal,
# Nearest to they: he, it, not, there, insightful, dumas, infinitesimals, perturbations,
# Nearest to which: this, who, that, it, there, also, booklets, rpgs,
# Nearest to history: puzzled, drucker, supplanting, popes, epitaph, banzer, model, eleven,
# Nearest to five: six, seven, eight, three, four, nine, zero, two,
# Nearest to would: can, will, could, but, should, to, may, invalidate,
# Nearest to be: have, is, blanca, was, lawsuits, become, diners, by,
# Nearest to he: it, desu, they, she, who, there, mcenroe, newington,
# Average loss at step 12000: 3.607961
# Average loss at step 14000: 3.571958
# Average loss at step 16000: 3.408690
# Average loss at step 18000: 3.457715
# Average loss at step 20000: 3.542719
# Nearest to i: ii, patterson, iii, blizzards, ministries, mistreatment, clap, we,
# Nearest to will: would, can, could, may, to, should, militant, creations,
# Nearest to six: four, seven, eight, five, nine, three, zero, two,
# Nearest to also: now, which, not, generally, disjunctive, hysteria, who, rove,
# Nearest to known: used, such, fijian, well, drysdale, concubine, turku, responsible,
# Nearest to as: when, spitzer, apartheid, uscis, pershing, fared, almaty, for,
# Nearest to up: ended, him, breve, amstrad, aveiro, xxiv, dissatisfaction, sed,
# Nearest to has: had, have, is, was, does, penrose, although, yitzhak,
# Nearest to his: their, her, its, the, appreciating, our, pineal, inv,
# Nearest to they: he, there, it, you, who, we, she, not,
# Nearest to which: that, this, what, it, there, who, also, these,
# Nearest to history: list, model, supplanting, puzzled, drucker, gravis, popes, historical,
# Nearest to five: six, seven, four, eight, three, two, zero, nine,
# Nearest to would: can, will, could, may, should, must, did, might,
# Nearest to be: have, been, by, were, is, become, was, are,
# Nearest to he: it, they, who, she, there, seafaring, desu, dormant,
# Average loss at step 22000: 3.502145
# Average loss at step 24000: 3.487585
# Average loss at step 26000: 3.486209
# Average loss at step 28000: 3.481026
# Average loss at step 30000: 3.501237
# Nearest to i: ii, we, iii, sociobiology, patterson, you, clap, blizzards,
# Nearest to will: would, can, may, could, should, must, andropov, militant,
# Nearest to six: four, eight, five, seven, nine, three, two, zero,
# Nearest to also: now, often, still, which, hysteria, disjunctive, mishap, actually,
# Nearest to known: used, well, such, regarded, responsible, regulus, drysdale, fijian,
# Nearest to as: when, spitzer, woolf, glyn, by, became, lib, popularizing,
# Nearest to up: him, ended, xxiv, marker, aveiro, emoticons, breve, punish,
# Nearest to has: had, have, is, was, does, penrose, having, suspends,
# Nearest to his: their, her, its, the, appreciating, s, our, your,
# Nearest to they: there, he, we, you, these, it, not, who,
# Nearest to which: this, that, what, it, these, also, there, but,
# Nearest to history: list, model, epitaph, peritoneum, banzer, puzzled, drucker, transmission,
# Nearest to five: four, seven, eight, six, three, nine, zero, two,
# Nearest to would: could, will, can, may, should, must, might, did,
# Nearest to be: have, been, develop, being, are, is, regis, were,
# Nearest to he: it, she, they, who, there, finally, desu, cents,
# Average loss at step 32000: 3.505062
# Average loss at step 34000: 3.498262
# Average loss at step 36000: 3.455636
# Average loss at step 38000: 3.300790
# Average loss at step 40000: 3.427816
# Nearest to i: ii, we, you, t, sociobiology, iii, clap, patterson,
# Nearest to will: would, can, may, could, should, must, to, argyll,
# Nearest to six: four, five, seven, eight, three, nine, two, zero,
# Nearest to also: now, often, which, still, actually, never, who, generally,
# Nearest to known: used, such, well, regarded, responsible, regulus, concubine, turku,
# Nearest to as: when, cookbook, estuary, spitzer, crossed, spp, uscis, nacional,
# Nearest to up: him, off, down, them, xxiv, emoticons, oedipus, marker,
# Nearest to has: had, have, was, is, having, yitzhak, suspends, does,
# Nearest to his: their, her, its, s, the, our, your, putin,
# Nearest to they: there, we, he, it, you, these, not, she,
# Nearest to which: that, this, what, also, it, often, there, these,
# Nearest to history: list, epitaph, model, forte, peritoneum, environment, mixolydian, selection,
# Nearest to five: six, seven, three, four, eight, two, nine, zero,
# Nearest to would: will, could, can, may, should, might, did, must,
# Nearest to be: been, have, being, is, were, become, was, by,
# Nearest to he: she, it, they, who, there, desu, landmarks, seafaring,
# Average loss at step 42000: 3.436530
# Average loss at step 44000: 3.445237
# Average loss at step 46000: 3.449562
# Average loss at step 48000: 3.354648
# Average loss at step 50000: 3.382579
# Nearest to i: you, ii, we, sociobiology, t, patterson, blizzards, clap,
# Nearest to will: would, can, could, may, should, must, did, shall,
# Nearest to six: eight, seven, four, five, three, nine, two, zero,
# Nearest to also: now, which, often, actually, still, who, largely, berry,
# Nearest to known: used, regarded, such, well, responsible, regulus, described, concubine,
# Nearest to as: spitzer, popularizing, crossed, pershing, cretians, spp, momentous, gross,
# Nearest to up: off, him, down, out, them, xxiv, parasites, emoticons,
# Nearest to has: had, have, was, is, does, having, suspends, although,
# Nearest to his: her, their, its, our, your, my, appreciating, the,
# Nearest to they: there, he, we, you, it, these, she, who,
# Nearest to which: that, this, what, also, who, these, it, still,
# Nearest to history: list, peritoneum, model, epitaph, transmission, mixolydian, forte, banzer,
# Nearest to five: four, six, eight, seven, three, zero, two, nine,
# Nearest to would: could, can, will, may, should, must, might, did,
# Nearest to be: being, been, have, was, become, were, choose, refer,
# Nearest to he: it, she, they, who, there, eventually, then, this,
# Average loss at step 52000: 3.435673
# Average loss at step 54000: 3.432927
# Average loss at step 56000: 3.438503
# Average loss at step 58000: 3.397553
# Average loss at step 60000: 3.392066
# Nearest to i: ii, you, we, sociobiology, t, blizzards, they, iii,
# Nearest to will: would, could, can, may, should, must, did, might,
# Nearest to six: eight, four, five, seven, nine, three, zero, two,
# Nearest to also: now, still, often, actually, currently, never, generally, usually,
# Nearest to known: used, regarded, such, well, responsible, described, regulus, considered,
# Nearest to as: by, when, spp, spitzer, fared, pershing, in, innovations,
# Nearest to up: off, him, out, down, them, xxiv, lets, statisticians,
# Nearest to has: had, have, was, having, is, does, suspends, legge,
# Nearest to his: her, their, its, our, my, your, embarrassing, the,
# Nearest to they: we, there, you, he, she, it, these, not,
# Nearest to which: that, this, what, these, however, it, there, located,
# Nearest to history: list, model, selection, forte, skiing, period, gravis, geography,
# Nearest to five: four, six, three, eight, seven, zero, nine, two,
# Nearest to would: will, could, can, may, should, must, might, did,
# Nearest to be: been, is, become, being, was, refer, are, demolish,
# Nearest to he: she, it, they, there, who, finally, eventually, we,
# Average loss at step 62000: 3.244773
# Average loss at step 64000: 3.258409
# Average loss at step 66000: 3.399749
# Average loss at step 68000: 3.393375
# Average loss at step 70000: 3.358751
# Nearest to i: ii, you, we, sociobiology, mistreatment, g, effector, distrito,
# Nearest to will: would, may, could, can, must, should, might, shall,
# Nearest to six: four, eight, seven, five, nine, three, two, zero,
# Nearest to also: still, now, often, which, never, actually, usually, sometimes,
# Nearest to known: used, regarded, such, responsible, well, described, seen, considered,
# Nearest to as: spp, interfaces, popularizing, keen, reinforce, by, officiated, scholarly,
# Nearest to up: off, down, out, him, them, lets, xxiv, back,
# Nearest to has: had, have, is, was, having, since, does, suspends,
# Nearest to his: her, their, its, my, your, our, appreciating, inv,
# Nearest to they: we, there, he, you, it, she, these, then,
# Nearest to which: that, this, what, these, also, but, and, however,
# Nearest to history: list, period, selection, forte, model, geography, peritoneum, encyclopedia,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to would: will, could, may, can, should, might, must, did,
# Nearest to be: been, were, become, being, is, develop, have, lawsuits,
# Nearest to he: she, it, they, there, who, finally, eventually, optimally,
# Average loss at step 72000: 3.377949
# Average loss at step 74000: 3.348880
# Average loss at step 76000: 3.324055
# Average loss at step 78000: 3.351505
# Average loss at step 80000: 3.381015
# Nearest to i: ii, we, you, iii, mistreatment, chromaticity, blizzards, v,
# Nearest to will: would, can, could, may, should, must, might, cannot,
# Nearest to six: five, seven, eight, four, three, nine, two, zero,
# Nearest to also: now, still, often, actually, which, never, sometimes, currently,
# Nearest to known: used, regarded, responsible, such, described, defined, referred, called,
# Nearest to as: spitzer, reeve, interfaces, generals, outright, bergen, wt, after,
# Nearest to up: off, out, down, them, him, lets, back, emoticons,
# Nearest to has: had, have, is, suspends, was, having, since, does,
# Nearest to his: her, their, its, my, your, our, the, appreciating,
# Nearest to they: we, he, you, there, she, it, these, matured,
# Nearest to which: this, that, what, also, these, but, based, actually,
# Nearest to history: list, period, selection, encyclopedia, philosophy, aspect, skiing, positivism,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to would: will, could, may, can, should, must, might, did,
# Nearest to be: been, become, have, being, were, develop, is, was,
# Nearest to he: she, it, they, there, who, eventually, finally, later,
# Average loss at step 82000: 3.404651
# Average loss at step 84000: 3.411866
# Average loss at step 86000: 3.388307
# Average loss at step 88000: 3.354677
# Average loss at step 90000: 3.369178
# Nearest to i: ii, we, you, g, iii, t, mistreatment, v,
# Nearest to will: would, can, could, must, may, should, might, cannot,
# Nearest to six: seven, eight, five, four, nine, three, two, zero,
# Nearest to also: now, still, often, actually, which, never, generally, sometimes,
# Nearest to known: regarded, used, such, described, responsible, well, referred, opposed,
# Nearest to as: woolf, bergen, reeve, plough, sailboat, pershing, keen, ibadi,
# Nearest to up: off, out, down, them, him, back, lets, emoticons,
# Nearest to has: had, have, is, having, was, does, since, suspends,
# Nearest to his: her, their, its, your, my, our, the, s,
# Nearest to they: we, he, there, you, she, it, these, matured,
# Nearest to which: that, this, what, also, but, who, usually, polydor,
# Nearest to history: list, philosophy, period, encyclopedia, tunic, selection, hindu, gal,
# Nearest to five: seven, four, eight, three, six, nine, two, zero,
# Nearest to would: could, will, can, may, should, might, must, did,
# Nearest to be: been, become, was, choose, have, is, being, develop,
# Nearest to he: she, it, they, there, who, later, eventually, finally,
# Average loss at step 92000: 3.397053
# Average loss at step 94000: 3.256450
# Average loss at step 96000: 3.362939
# Average loss at step 98000: 3.244578
# Average loss at step 100000: 3.355294
# Nearest to i: we, you, ii, iii, chromaticity, they, t, mistreatment,
# Nearest to will: would, can, could, must, may, should, might, cannot,
# Nearest to six: seven, four, eight, five, nine, two, three, zero,
# Nearest to also: now, actually, still, often, never, generally, sometimes, which,
# Nearest to known: regarded, used, such, described, responsible, defined, called, opposed,
# Nearest to as: reeve, ibadi, spp, scholarly, when, tsing, interfaces, sclerosis,
# Nearest to up: off, out, down, them, him, back, nowhere, andromache,
# Nearest to has: had, have, is, was, since, having, suspends, contains,
# Nearest to his: her, their, your, my, its, our, the, s,
# Nearest to they: we, there, he, you, she, it, i, these,
# Nearest to which: that, this, what, usually, but, these, also, actually,
# Nearest to history: list, tunic, philosophy, encyclopedia, selection, hindu, geography, period,
# Nearest to five: four, seven, six, eight, three, two, zero, nine,
# Nearest to would: will, could, may, can, might, should, must, did,
# Nearest to be: been, become, have, refer, represent, are, is, being,
# Nearest to he: she, it, they, there, who, never, we, eventually,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
#First generate training batches from dataset.
#We need to predict the target word from context
#[context1 target context2]
#We will produce 2 vectors:
# - batch of size "batch_size" with context words
# - labels with size batch_size // num_skips with target words
#such that batch[0] and batch[1] correspond to labels[0], batch[2] and batch[3] to labels[1]... for skip_window=1
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size // num_skips, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[target] #swap batch and label from n-gram model
    labels[i , 0] = buffer[skip_window] #only keep one label per group
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8//num_skips)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a']
#     labels: ['originated', 'as', 'a', 'term']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['anarchism', 'originated', 'a', 'term', 'as', 'originated', 'of', 'term']
#     labels: ['as', 'a']

# %%
#Train a CBOW model
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size//num_skips, 1]) #resize train_labels to labels size
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  #Reduce embeddings matrix by sumation of datasets elements with same label. We create the ids to sum by.
  ids = tf.constant([x // num_skips  for x in range(batch_size)]) #For batch_size=8 and num_skips=2 we get [0,0,1,1,2,2,3,3,4,4]
  embed = tf.segment_sum(embed, ids)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From C:\Users\Jesus\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %%
#Perform the training
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.599646
# Nearest to b: valine, khaldun, shots, progesterone, herbrand, basingstoke, builder, prolific,
# Nearest to are: quest, colonists, jacob, kur, weisstein, tl, laissez, nazarbayev,
# Nearest to such: pwnage, medal, dietrich, moreover, malawian, longitudes, parallelism, turboprop,
# Nearest to to: operators, farsi, tehran, sextilis, transposed, hieroglyph, botany, excommunicate,
# Nearest to or: revamp, plugins, lagoon, aromatherapy, ordnance, closures, macaulay, disciples,
# Nearest to a: adjacency, allophone, toledo, gimlin, multiplicity, paladins, pogo, titanium,
# Nearest to zero: autonomy, sophia, hare, partners, contingent, chieftains, logico, gabor,
# Nearest to only: uttered, musicals, fen, egan, cannibals, musk, gein, reconstruct,
# Nearest to from: belleville, goodman, packet, brennan, isolated, caricom, subtext, shafts,
# Nearest to one: eliot, bullseye, glastonbury, enduring, sentience, tirthankaras, game, likewise,
# Nearest to eight: log, entangled, mallow, longbows, unconditional, ingeborg, bayonne, condenses,
# Nearest to people: gautama, coined, wilbur, concocted, magazine, detective, educating, maasai,
# Nearest to be: reproduce, gaze, culprits, correlates, replicants, nostrand, generically, crb,
# Nearest to been: bla, bestial, acetate, mispronounced, ois, gmt, roebuck, rune,
# Nearest to into: condoned, minimise, kokomo, archimedes, distinctions, triode, toni, tex,
# Nearest to new: democrats, anchor, siculus, bare, inwo, snowmobile, dijkstra, tl,
# Average loss at step 2000: 4.211332
# Average loss at step 4000: 3.639823
# Average loss at step 6000: 3.538455
# Average loss at step 8000: 3.381688
# Average loss at step 10000: 3.289569
# Nearest to b: d, valine, builder, bankhead, morpheus, harrington, rappers, cluny,
# Nearest to are: were, is, have, was, cooperated, do, dynamism, kislev,
# Nearest to such: known, adulthood, daffodils, well, these, creutzfeldt, recede, supple,
# Nearest to to: tehran, will, cuttings, dhaka, could, session, hamm, can,
# Nearest to or: and, than, fractured, handing, nigh, sharpen, causing, caveats,
# Nearest to a: clytemnestra, the, ovation, bok, his, farsi, decentralisation, abbeys,
# Nearest to zero: nine, eight, five, six, three, seven, four, two,
# Nearest to only: rhetoric, pak, birthdays, bosnia, comit, charters, honored, gein,
# Nearest to from: into, on, soap, intracranial, belleville, packet, by, eubank,
# Nearest to one: two, three, six, eight, four, five, outlawed, skins,
# Nearest to eight: nine, six, seven, five, four, three, two, zero,
# Nearest to people: americanization, films, countries, procellariiformes, vegetables, inns, dooley, overturn,
# Nearest to be: have, appear, not, become, is, curried, been, were,
# Nearest to been: was, husband, elegy, be, futuna, were, become, vla,
# Nearest to into: from, triode, terabytes, kokomo, with, aleksandr, by, as,
# Nearest to new: usda, desired, siculus, appletalk, euphrates, alkyl, warship, darrow,
# Average loss at step 12000: 3.267859
# Average loss at step 14000: 3.245925
# Average loss at step 16000: 3.025569
# Average loss at step 18000: 3.061133
# Average loss at step 20000: 3.150837
# Nearest to b: d, bian, bedroom, builder, bologna, cp, apoplexy, ipa,
# Nearest to are: were, is, include, have, but, including, be, biggs,
# Nearest to such: known, well, these, daffodils, quartets, regarded, audi, measured,
# Nearest to to: would, unloading, could, may, should, tehran, hutterite, will,
# Nearest to or: and, than, azhar, scudetto, hues, ide, activation, lefebvre,
# Nearest to a: any, the, another, mycenaean, magnify, no, banquo, sioux,
# Nearest to zero: five, seven, six, three, eight, four, nine, two,
# Nearest to only: rhetoric, aficionados, rum, assumed, wag, humanist, aes, sometime,
# Nearest to from: at, into, under, between, acetaminophen, by, on, fried,
# Nearest to one: two, four, three, eight, seven, five, six, nine,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to people: you, countries, procellariiformes, others, things, maloney, hang, analgesia,
# Nearest to be: have, become, been, refer, develop, being, were, cascading,
# Nearest to been: become, were, be, futuna, vla, husband, worthies, elegy,
# Nearest to into: through, from, with, terabytes, on, down, angelus, nasi,
# Nearest to new: usda, euphrates, darrow, transnistrian, sunny, imperial, disagreements, sheets,
# Average loss at step 22000: 3.117428
# Average loss at step 24000: 3.077052
# Average loss at step 26000: 3.052281
# Average loss at step 28000: 3.064251
# Average loss at step 30000: 3.080589
# Nearest to b: d, harbored, incorporeal, auratus, builder, lott, kong, regress,
# Nearest to are: were, have, include, is, although, pup, lamarck, differ,
# Nearest to such: well, regarded, these, known, many, some, creutzfeldt, nitrogenous,
# Nearest to to: would, may, should, must, can, could, draws, might,
# Nearest to or: and, nonsignatory, busing, kibbutz, draining, azhar, lcds, moneo,
# Nearest to a: the, fathom, no, textbook, truetype, clos, another, bok,
# Nearest to zero: eight, six, five, seven, four, nine, three, th,
# Nearest to only: habilis, july, but, november, birthdays, totalling, henrietta, wag,
# Nearest to from: into, under, before, shafts, between, of, intracranial, ossetia,
# Nearest to one: two, seven, four, six, three, nine, five, eight,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to people: countries, jews, you, americans, years, insert, laughed, paige,
# Nearest to be: have, become, refers, been, were, being, produce, escorted,
# Nearest to been: become, be, vla, encroached, never, futuna, were, was,
# Nearest to into: from, through, within, under, back, angelus, triode, down,
# Nearest to new: bandit, senior, euphrates, second, nicaea, abe, limit, special,
# Average loss at step 32000: 3.077614
# Average loss at step 34000: 3.049710
# Average loss at step 36000: 2.999746
# Average loss at step 38000: 2.793736
# Average loss at step 40000: 2.974819
# Nearest to b: d, c, r, w, volume, m, namco, UNK,
# Nearest to are: were, is, have, galloping, include, being, be, engages,
# Nearest to such: well, known, these, adulthood, quartets, orientational, many, follows,
# Nearest to to: must, will, could, unloading, should, ayatollah, may, might,
# Nearest to or: and, than, fencers, inhibits, cognitivism, pulsar, a, osama,
# Nearest to a: the, another, any, every, wooing, magnify, no, refine,
# Nearest to zero: seven, five, eight, nine, six, four, three, th,
# Nearest to only: frac, honored, begin, chlorus, hound, watt, changes, birthdays,
# Nearest to from: into, between, of, under, intracranial, regarding, about, numerically,
# Nearest to one: four, two, six, seven, eight, five, nine, three,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to people: men, someone, person, children, weeks, sweat, things, reducible,
# Nearest to be: have, become, been, get, being, are, were, escorted,
# Nearest to been: become, never, be, begun, were, already, futuna, suffered,
# Nearest to into: through, from, triode, back, within, mouthwash, off, mauritians,
# Nearest to new: imperial, columbians, third, darrow, commutativity, second, reductionist, fourth,
# Average loss at step 42000: 2.975853
# Average loss at step 44000: 2.993251
# Average loss at step 46000: 2.981137
# Average loss at step 48000: 2.872730
# Average loss at step 50000: 2.895551
# Nearest to b: d, f, c, w, x, gerald, ferranti, intrauterine,
# Nearest to are: were, is, have, insulting, carps, engages, kislev, be,
# Nearest to such: well, known, regarded, these, ingested, follows, being, adulthood,
# Nearest to to: could, will, can, may, must, would, unloading, hutterite,
# Nearest to or: and, azhar, than, though, instantiation, methuen, arboretum, rafael,
# Nearest to a: another, the, flexible, magnify, ovation, attractor, paramilitaries, relatively,
# Nearest to zero: six, seven, eight, five, four, three, nine, two,
# Nearest to only: always, dieu, either, transhumanism, nibble, rhetoric, baserunner, besht,
# Nearest to from: into, in, acetaminophen, through, between, under, during, ecmascript,
# Nearest to one: two, eight, seven, four, six, five, three, nine,
# Nearest to eight: six, seven, nine, four, two, five, zero, three,
# Nearest to people: men, words, children, things, countries, jews, writers, angels,
# Nearest to be: have, remain, become, introduce, refer, barbour, provide, was,
# Nearest to been: become, remained, already, suffered, was, encroached, be, begun,
# Nearest to into: through, from, within, triode, back, over, towards, under,
# Nearest to new: imperial, third, former, euphrates, old, talmudic, second, grind,
# Average loss at step 52000: 2.953787
# Average loss at step 54000: 2.933287
# Average loss at step 56000: 2.963304
# Average loss at step 58000: 2.874865
# Average loss at step 60000: 2.894137
# Nearest to b: c, p, rarities, f, w, geq, d, cp,
# Nearest to are: were, is, have, including, italiano, cielo, include, shimon,
# Nearest to such: well, known, many, follows, regarded, described, certain, including,
# Nearest to to: may, unloading, hutterite, would, magnetron, might, tehran, will,
# Nearest to or: and, than, like, piron, telegraphs, jomo, cognitivism, conspicuously,
# Nearest to a: any, the, every, another, magnify, kanal, this, denoted,
# Nearest to zero: five, eight, four, six, seven, nine, three, colspan,
# Nearest to only: until, gauls, always, deafness, all, intellivision, mifune, first,
# Nearest to from: into, under, through, within, cav, in, workhorse, tsinghua,
# Nearest to one: two, eight, seven, five, nine, six, three, four,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to people: men, women, players, children, those, writers, others, jews,
# Nearest to be: been, remain, become, have, produce, contribute, is, introduce,
# Nearest to been: become, be, remained, already, horned, odi, was, had,
# Nearest to into: from, towards, within, through, back, under, beyond, across,
# Nearest to new: imperial, third, euphrates, fourth, talmudic, second, particular, nonmetals,
# Average loss at step 62000: 2.680009
# Average loss at step 64000: 2.698386
# Average loss at step 66000: 2.876249
# Average loss at step 68000: 2.891822
# Average loss at step 70000: 2.840423
# Nearest to b: p, neil, n, z, intrauterine, f, h, x,
# Nearest to are: were, is, have, include, musashi, be, contain, kislev,
# Nearest to such: known, these, well, certain, many, regarded, follows, themselves,
# Nearest to to: would, will, unloading, robbing, might, sampa, dining, against,
# Nearest to or: and, while, azhar, than, arg, hues, stockholders, quaker,
# Nearest to a: the, another, fabrics, draugr, this, polytheism, vehicular, paramilitaries,
# Nearest to zero: eight, five, four, seven, six, nine, three, colspan,
# Nearest to only: always, cracker, endeavoured, gauls, mag, transhumanism, never, dieu,
# Nearest to from: through, into, under, toward, during, intracranial, acetaminophen, dillon,
# Nearest to one: two, seven, four, six, eight, nine, five, three,
# Nearest to eight: nine, seven, six, five, four, zero, three, two,
# Nearest to people: men, women, children, members, citizens, critics, others, writers,
# Nearest to be: been, become, being, is, have, remain, introduce, were,
# Nearest to been: become, remained, be, was, were, already, arminian, recently,
# Nearest to into: through, within, halas, from, under, towards, back, toward,
# Nearest to new: setup, legality, different, separate, backlit, certain, streams, clarifying,
# Average loss at step 72000: 2.864023
# Average loss at step 74000: 2.821178
# Average loss at step 76000: 2.817944
# Average loss at step 78000: 2.824871
# Average loss at step 80000: 2.855608
# Nearest to b: c, neil, geq, d, myrna, bartender, gary, intrauterine,
# Nearest to are: were, have, contain, include, is, although, wftu, kislev,
# Nearest to such: well, follows, these, regarded, known, opposed, themselves, serve,
# Nearest to to: should, unloading, audiogalaxy, help, magnetron, may, hutterite, mpa,
# Nearest to or: and, acrobatic, fencers, mvs, though, otranto, draining, azhar,
# Nearest to a: another, the, every, polytheism, hoplite, smiley, clytemnestra, wooing,
# Nearest to zero: seven, five, six, eight, four, three, nine, two,
# Nearest to only: last, always, best, april, viol, refuges, mag, ivar,
# Nearest to from: into, through, within, between, before, during, in, via,
# Nearest to one: two, six, seven, four, three, five, eight, qquad,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to people: men, children, women, someone, christians, jews, inhabitants, persons,
# Nearest to be: have, been, remain, produce, being, introduce, become, provide,
# Nearest to been: become, remained, be, already, were, begun, was, futuna,
# Nearest to into: through, within, from, towards, back, onto, upon, across,
# Nearest to new: particular, different, old, nonmetals, imperial, setup, senior, backlit,
# Average loss at step 82000: 2.878283
# Average loss at step 84000: 2.891559
# Average loss at step 86000: 2.855111
# Average loss at step 88000: 2.805239
# Average loss at step 90000: 2.814863
# Nearest to b: neil, geq, particularity, c, f, paleontology, snakes, charisma,
# Nearest to are: were, is, include, have, contain, wftu, differ, isin,
# Nearest to such: well, known, follows, opposed, soon, serve, interpreted, nitrogenous,
# Nearest to to: hutterite, must, would, could, will, shall, help, through,
# Nearest to or: and, draining, than, azhar, traitor, arboretum, while, hues,
# Nearest to a: the, every, another, any, incommunicado, paramilitaries, relatively, truetype,
# Nearest to zero: seven, eight, five, six, four, three, nine, u,
# Nearest to only: always, latter, every, mag, best, besht, birthdays, lunatic,
# Nearest to from: through, into, under, within, during, towards, after, between,
# Nearest to one: seven, two, six, four, five, eight, three, nine,
# Nearest to eight: nine, seven, five, six, four, three, zero, two,
# Nearest to people: women, men, children, christians, person, citizens, someone, writers,
# Nearest to be: lead, have, become, relate, introduce, reach, been, create,
# Nearest to been: become, already, remained, previously, be, was, were, publicly,
# Nearest to into: through, from, within, onto, towards, invocations, using, around,
# Nearest to new: particular, elam, provably, cede, modern, nga, redox, talmudic,
# Average loss at step 92000: 2.862786
# Average loss at step 94000: 2.687622
# Average loss at step 96000: 2.825808
# Average loss at step 98000: 2.696791
# Average loss at step 100000: 2.809602
# Nearest to b: d, romantic, frye, krypton, superconductor, c, gary, apeiron,
# Nearest to are: were, differ, have, exist, is, contain, while, include,
# Nearest to such: well, known, follows, opposed, many, certain, serve, nitrogenous,
# Nearest to to: can, could, will, should, must, would, hutterite, towards,
# Nearest to or: and, hearted, than, vs, handel, otranto, xie, azhar,
# Nearest to a: the, another, any, this, paramilitaries, attractor, finno, relatively,
# Nearest to zero: five, seven, eight, four, six, three, nine, two,
# Nearest to only: best, latter, either, no, inverting, shots, you, totalling,
# Nearest to from: in, through, during, via, into, within, serra, ossetia,
# Nearest to one: two, seven, nine, eight, four, five, six, three,
# Nearest to eight: nine, seven, six, four, five, three, zero, two,
# Nearest to people: children, men, countries, women, individuals, persons, person, christians,
# Nearest to be: contain, produce, have, remain, being, been, become, reach,
# Nearest to been: become, already, remained, recently, be, begun, was, were,
# Nearest to into: through, onto, within, towards, from, beyond, invocations, triode,
# Nearest to new: modern, fourth, nonmetals, particular, sporting, incontinence, electrochemistry, sunny,
